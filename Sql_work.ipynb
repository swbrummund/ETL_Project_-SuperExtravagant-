# %%
import os
import pandas as pd
import sqlite3 as sql
# from sqlite3 import Error
import sqlalchemy

# %%
def MyConn(dbstring):
    conn = None
    try:
        conn=sql.connect(dbstring)
        return conn
    except Error as e:
        print(e)

    return conn

def create_table(conn, tableqry):
    try:
        c = conn.cursor()
        c.execute(tableqry)
    except Error as e:
        print(e)

# %%
    ##establish db connection
    #dbstring=""
    #conn=MyConn(dbstring)
    
    ##create the tables needed for the project
    ##cocktails
    #create_table_query="CREATE TABLE 'Cocktails' ('ID'	INTEGER PRIMARY KEY AUTOINCREMENT, 'City_ID' INTEGER, 'Name' TEXT, 'Ingredients' TEXT)"
    #create_table(conn,create_table_query)



    #Read in Seth's tables --- staging 
    #1- read in the cleaned csv to a dataframe
cwd=os.getcwd()
filepath=os.path.join(cwd,'csv_output','cocktails_cleaned.csv')
filepath
df=pd.read_csv('.\csv_output\cocktails_cleaned.csv')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-22-059a9ae7e847> in <module>
#      15 filepath=os.path.join(cwd,'csv_output','cocktails_cleaned.csv')
#      16 filepath
# ---> 17 df=pd.read_csv('.\csv_output\cocktails_cleaned.csv')
#      18
#      19
#
# ...
